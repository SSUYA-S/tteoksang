# %%
import numpy as np
import pandas as pd
import json
pd.options.display.float_format = '{:,}'.format
pd.set_option('display.max_rows', None)

# %%
with open("data/response.json", 'rt', encoding='utf-8') as f:
  data = json.load(f)
  
product_info_data = pd.json_normalize(data, record_path=['Grid_20171128000000000572_1','row'])
product_info_data = product_info_data.drop(['M_DISTCTNS_ITM', 'PRDLST_CL', 'MTC_NM', 'MAIN_SPCIES_NM', 'EFFECT', 'PURCHASE_MTH', 'COOK_MTH', 'TRT_MTH', 'URL', 'IMG_URL', 'REGIST_DE'], axis=1)
product_info_data['M_DISTCTNS'] = product_info_data['M_DISTCTNS'].apply(lambda x: x.replace("월", ""))
product_info_data['PRDCTN__ERA'] = product_info_data["PRDCTN__ERA"].apply(lambda x: x.replace("월", ""))
product_info_data['PRDCTN__ERA'] = product_info_data['PRDCTN__ERA'].where(product_info_data['PRDCTN__ERA'].str.contains(r'^\d+~\d+$'), np.nan)

# %%
display(product_info_data)
# Out:
#      ROW_NUM  IDNTFC_NO PRDLST_NM M_DISTCTNS PRDCTN__ERA
# 0          1     227366       산마늘          4         3~5
# 1          2     227365        울외          6         3~7
# 2          3     227364        밤콩          7         NaN
# 3          4     227363        노각          4         4~7
# 4          5     227362        삼채          6         NaN
# 5          6     227361       방아잎          8        8~11
# 6          7     227360      돼지감자         12         NaN
# 7          8     227358        섬초         11        11~3
# 8          9     227354     아마란스          10         NaN
# 9         10     227351       솔부추          1        12~1
# 10        11     227350       청경채         10         NaN
# 11        12     227349       히카마         10         NaN
# 12        13     227348        동아          9        9~11
# 13        14     227347        청귤          8         8~9
# 14        15     227345        호밀          8         8~9
# 15        16     227344       구기자          7        7~11
# 16        17     227343     보리수열매          6         NaN
# 17        18     227342        체리          6         5~6
# 18        19     227341        곰취          5         4~6
# 19        20     227340       토마토          7         7~9
# 20        21     227338      목이버섯          3         3~6
# 21        22     227337        봄동          2         2~4
# 22        23     227336      취청오이          1        12~2
# 23        24     227335       레드향          1         NaN
# 24        25     227334     방울양배추          1         1~2
# 25        26     219967        기장          9        8~10
# 26        27     219966         밀          5         NaN
# 27        28     219965        보리          6         NaN
# 28        29     219964        수수         10        9~10
# 29        30     219963         쌀         10        9~10
# 30        31     219962         조          9        9~10
# 31        32     219960        찹쌀          9        9~10
# 32        33     219959        흑미          9        9~10
# 33        34     219958       결명자         11        9~11
# 34        35     219957        아욱          7         7~8
# 35        36     219956        살구          6         6~7
# 36        37     219955        앵두          6         6~7
# 37        38     219954      파인애플          4         3~9
# 38        39     219953      블루베리          7         7~9
# 39        40     219952       호박씨          3        3~10
# 40        41     219951       머위대          3         3~4
# 41        42     219950        대두         10         NaN
# 42        43     219949        백태         10        9~10
# 43        44     219948       강낭콩          7         6~7
# 44        45     219947      쥐눈이콩         11       10~11
# 45        46     219946        강황         11       10~11
# 46        47     219945        깻잎          7        1~12
# 47        48     219944        대파         10        9~12
# 48        49     219943        상추          5         5~8
# 49        50     219942       샐러리          7         NaN
# 50        51     219941       엉겅퀴          6         5~7
# 51        52     219940        적채          6         3~6
# 52        53     219939       총각무         11       10~12
# 53        54     219938       치커리          8         7~8
# 54        55     219937       토란대          9        9~10
# 55        56     219936        콩잎         10        9~10
# 56        57     219935       수세미         10        9~11
# 57        58     219934        마늘          4         3~5
# 58        59     219933   노루궁뎅이버섯          9        8~10
# 59        60     219932     느타리버섯         10        1~12
# 60        61     219931      팽이버섯          1        1~12
# 61        62     219930      영지버섯          9        1~12
# 62        63     219929      능이버섯          9        1~12
# 63        64     219928      가지버섯         11       10~11
# 64        65     219927      상황버섯         12        1~12
# 65        66     219926      숙주나물          5        6~10
# 66        67     219925     새송이버섯         10        1~12
# 67        68     219892      고추냉이          7         6~7
# 68        69     219849         칡          9        9~10
# 69        70     219827     양송이버섯         10        1~12
# 70        71     219822        피망          5        4~12
# 71        72     219924        귀리          9        9~10
# 72        73     219923        참깨          9         NaN
# 73        74     219922        머루         10        9~10
# 74        75     219921        생강         10        8~11
# 75        76     219920        땅콩         10       10~11
# 76        77     219919        사과          9        7~11
# 77        78     219918       서리태         10       10~11
# 78        79     219917        들깨         10         NaN
# 79        80     219916         밤         10        8~10
# 80        81     219915        순무         10       10~11
# 81        82     219914        녹두         10        9~10
# 82        83     219913        모과         10        9~10
# 83        84     219912        메밀         10       10~11
# 84        85     219911        토란         10         NaN
# 85        86     219910      고들빼기         10       10~12
# 86        87     219909       홍고추          8        6~11
# 87        88     219908        호두         10        9~10
# 88        89     219907         갓         10        9~12
# 89        90     219906      표고버섯          9        9~10
# 90        91     219905        포도          8        8~10
# 91        92     219904         팥          9        9~10
# 92        93     219903         잣         11        8~12
# 93        94     219902        인삼          9        9~10
# 94        95     219901        유자         11       11~12
# 95        96     219900        참외          6         6~8
# 96        97     219899        은행          9        9~10
# 97        98     219898       참나물          8         4~9
# 98        99     219897        율무          9        9~10
# 99       100     219896        울금         11         NaN
# 100      101     219895     얼갈이배추         11       11~12
# 101      102     219894    여주(고야)          8         6~8
# 102      103     219893       오미자          9        9~10
# 103      104     219891       알로에          8         7~8
# 104      105     219890        야콘          9        9~10
# 105      106     219889        석류         11        9~12
# 106      107     219888  신선초(명일엽)          8         8~9
# 107      108     219887        수박          7         6~8
# 108      109     219886         배          9        8~10
# 109      110     219885       복숭아          8         6~8
# 110      111     219884        배추         11       11~12
# 111      112     219883       무화과          9        9~10
# 112      113     219882     방울토마토          6         6~9
# 113      114     219881         마         11       10~11
# 114      115     219880        대추          9        9~10
# 115      116     219879         무         11       10~11
# 116      117     219878        멜론          8        7~10
# 117      118     219877       단호박         11        6~12
# 118      119     219876      파프리카         11        5~11
# 119      120     219875       고구마          9        9~10
# 120      121     219874        자두          7         7~8
# 121      122     219873     늙은 호박         11        8~11
# 122      123     219872        열무          6         5~6
# 123      124     219871        용과          7        7~10
# 124      125     219870      애플망고          6        5~10
# 125      126     219869       옥수수          7         7~9
# 126      127     219868        오이          5         5~8
# 127      128     219867       산딸기          6         NaN
# 128      129     219866        부추          6        6~10
# 129      130     219865        양파          7         4~7
# 130      131     219864         감         11        9~11
# 131      132     219863       애호박          7        6~10
# 132      133     219862       복분자          6         6~8
# 133      134     219861      아로니아          7         7~9
# 134      135     219860      비름나물          7         7~9
# 135      136     219859        매실          6         5~7
# 136      137     219858       도라지          7         7~9
# 137      138     219857      꽈리고추          7         7~8
# 138      139     219856        감자          7        6~10
# 139      140     219855        가지          7        6~10
# 140      141     219854        근대          6         6~8
# 141      142     219853       곤드레          6         5~6
# 142      143     219852       호박잎          5         5~9
# 143      144     219851        하귤          5         4~5
# 144      145     219850       취나물          5         3~5
# 145      146     219848       완두콩          4        11~4
# 146      147     219847        쪽파          5         NaN
# 147      148     219846    아스파라거스          4         4~5
# 148      149     219845        죽순          5         5~6
# 149      150     219844       씀바귀          4         3~4
# 150      151     219843        오디          5         NaN
# 151      152     219842         쑥          4         3~4
# 152      153     219841       양배추          5         5~7
# 153      154     219840        머위          4         3~4
# 154      155     219839        쑥갓          5         5~6
# 155      156     219838        두릅          4         4~5
# 156      157     219837      방풍나물          5         NaN
# 157      158     219836        더덕          4         3~4
# 158      159     219835       마늘종          5         4~5
# 159      160     219834        냉이          4         3~4
# 160      161     219833      고구마순          5         5~6
# 161      162     219832  껍질콩(그린빈)          4        4~10
# 162      163     219831      세발나물          3        12~3
# 163      164     219830        비트          3         3~6
# 164      165     219829       고사리          4         4~6
# 165      166     219828      유채나물          2         2~3
# 166      167     219826       돌나물          3         3~4
# 167      168     219825       미나리          3         3~4
# 168      169     219824        달래          3         3~4
# 169      170     219823        딸기          2         1~5
# 170      171     219821       천혜향          2         2~3
# 171      172     219820       한라봉          2        12~3
# 172      173     219819        연근          2         9~3
# 173      174     219818        레몬          1        10~1
# 174      175     219817       시금치          2        11~2
# 175      176     219816        우엉          1         1~3
# 176      177     219815        감귤          1        10~3
# 177      178     219814        당근         12       10~12
# 178      179     219813      브로콜리         12        9~12
# 179      180     219812       콜라비         12       11~12
# 180      181     219811     콜리플라워         12        9~12
# 181      182     219810        키위         12       10~12

# %%
product_code_data = pd.read_csv('data/productname.csv')

# %%
display(product_code_data)
# Out:
#     PRODUCT_CODE PRODUCT_NAME
# 0            111            쌀
# 1            112           찹쌀
# 2            141            콩
# 3            142            팥
# 4            143           녹두
# 5            144           메밀
# 6            151          고구마
# 7            152           감자
# 8            161           귀리
# 9            113          혼합곡
# 10           162           보리
# 11           163           수수
# 12           164           율무
# 13           114           기장
# 14           211           배추
# 15           212          양배추
# 16           279        알배기배추
# 17           280         브로콜리
# 18           213          시금치
# 19           214           상추
# 20           215        얼갈이배추
# 21           216            갓
# 22           221           수박
# 23           222           참외
# 24           223           오이
# 25           224           호박
# 26           225          토마토
# 27           226           딸기
# 28           231            무
# 29           232           당근
# 30           233           열무
# 31           241          건고추
# 32           242          풋고추
# 33           243         붉은고추
# 34           244          피마늘
# 35           258      깐마늘(국산)
# 36           259      깐마늘(수입)
# 37           245           양파
# 38           246            파
# 39           247           생강
# 40           248         고춧가루
# 41           251           가지
# 42           252          미나리
# 43           253           깻잎
# 44           254           부추
# 45           255           피망
# 46           256         파프리카
# 47           257           멜론
# 48           261         브로콜리
# 49           262          양상추
# 50           263          청경채
# 51           264           케일
# 52           265          콩나물
# 53           422        방울토마토
# 54           217           연근
# 55           218           우엉
# 56           266         절임배추
# 57           312           참깨
# 58           313           들깨
# 59           314           땅콩
# 60           315        느타리버섯
# 61           316         팽이버섯
# 62           317        새송이버섯
# 63           318           호두
# 64           319          아몬드
# 65           321        양송이버섯
# 66           322         표고버섯
# 67           411           사과
# 68           412            배
# 69           413          복숭아
# 70           414           포도
# 71           415           감귤
# 72           416           단감
# 73           418          바나나
# 74           419          참다래
# 75           420         파인애플
# 76           421          오렌지
# 77           423           자몽
# 78           424           레몬
# 79           425           체리
# 80           426          건포도
# 81           427        건블루베리
# 82           428           망고
# 83           430         아보카도
# 84           429         블루베리

# %%
def month_to_Season(x: int) -> str:
  if pd.isna(x):
    return 'ALL'
  
  if type(x) == str:
    x = int(x)

  if x in [12, 1, 2]:
    return 'WINTER'
  elif x in [3, 4, 5]:
    return 'SPRING'
  elif x in [6, 7, 8]:
    return 'SUMMER'
  else:
    return 'FALL'
  
def era_to_bitmask(x: str) -> int:
  result = 0
  if pd.isna(x):
    return result
  
  start = 0
  end = 0
  
  temp = list(map(int,x.split(sep='~')))
    
  if len(temp) == 1:
    start = temp[0]
    end = temp[0]
  else:
    start = temp[0]
    end = temp[1]
      
  for i in range(start, end + 1):
    bit = 1
    result += (bit << i)
      
  return result

# %%
product_info = pd.merge(left=product_code_data, right=product_info_data,how="left", left_on='PRODUCT_NAME', right_on='PRDLST_NM')
product_info = product_info.drop(['IDNTFC_NO', 'PRDLST_NM', 'ROW_NUM'], axis=1)
product_info['M_DISTCTNS'] = product_info['M_DISTCTNS'].apply(month_to_Season)
product_info['PRDCTN__ERA'] = product_info['PRDCTN__ERA'].apply(era_to_bitmask)

# %%
display(product_info)
# Out:
#     PRODUCT_CODE PRODUCT_NAME M_DISTCTNS  PRDCTN__ERA
# 0            111            쌀       FALL         1536
# 1            112           찹쌀       FALL         1536
# 2            141            콩        ALL            0
# 3            142            팥       FALL         1536
# 4            143           녹두       FALL         1536
# 5            144           메밀       FALL         3072
# 6            151          고구마       FALL         1536
# 7            152           감자     SUMMER         1984
# 8            161           귀리       FALL         1536
# 9            113          혼합곡        ALL            0
# 10           162           보리     SUMMER            0
# 11           163           수수       FALL         1536
# 12           164           율무       FALL         1536
# 13           114           기장       FALL         1792
# 14           211           배추       FALL         6144
# 15           212          양배추     SPRING          224
# 16           279        알배기배추        ALL            0
# 17           280         브로콜리     WINTER         7680
# 18           213          시금치     WINTER            0
# 19           214           상추     SPRING          480
# 20           215        얼갈이배추       FALL         6144
# 21           216            갓       FALL         7680
# 22           221           수박     SUMMER          448
# 23           222           참외     SUMMER          448
# 24           223           오이     SPRING          480
# 25           224           호박        ALL            0
# 26           225          토마토     SUMMER          896
# 27           226           딸기     WINTER           62
# 28           231            무       FALL         3072
# 29           232           당근     WINTER         7168
# 30           233           열무     SUMMER           96
# 31           241          건고추        ALL            0
# 32           242          풋고추        ALL            0
# 33           243         붉은고추        ALL            0
# 34           244          피마늘        ALL            0
# 35           258      깐마늘(국산)        ALL            0
# 36           259      깐마늘(수입)        ALL            0
# 37           245           양파     SUMMER          240
# 38           246            파        ALL            0
# 39           247           생강       FALL         3840
# 40           248         고춧가루        ALL            0
# 41           251           가지     SUMMER         1984
# 42           252          미나리     SPRING           24
# 43           253           깻잎     SUMMER         8190
# 44           254           부추     SUMMER         1984
# 45           255           피망     SPRING         8176
# 46           256         파프리카       FALL         4064
# 47           257           멜론     SUMMER         1920
# 48           261         브로콜리     WINTER         7680
# 49           262          양상추        ALL            0
# 50           263          청경채       FALL            0
# 51           264           케일        ALL            0
# 52           265          콩나물        ALL            0
# 53           422        방울토마토     SUMMER          960
# 54           217           연근     WINTER            0
# 55           218           우엉     WINTER           14
# 56           266         절임배추        ALL            0
# 57           312           참깨       FALL            0
# 58           313           들깨       FALL            0
# 59           314           땅콩       FALL         3072
# 60           315        느타리버섯       FALL         8190
# 61           316         팽이버섯     WINTER         8190
# 62           317        새송이버섯       FALL         8190
# 63           318           호두       FALL         1536
# 64           319          아몬드        ALL            0
# 65           321        양송이버섯       FALL         8190
# 66           322         표고버섯       FALL         1536
# 67           411           사과       FALL         3968
# 68           412            배       FALL         1792
# 69           413          복숭아     SUMMER          448
# 70           414           포도     SUMMER         1792
# 71           415           감귤     WINTER            0
# 72           416           단감        ALL            0
# 73           418          바나나        ALL            0
# 74           419          참다래        ALL            0
# 75           420         파인애플     SPRING         1016
# 76           421          오렌지        ALL            0
# 77           423           자몽        ALL            0
# 78           424           레몬     WINTER            0
# 79           425           체리     SUMMER           96
# 80           426          건포도        ALL            0
# 81           427        건블루베리        ALL            0
# 82           428           망고        ALL            0
# 83           430         아보카도        ALL            0
# 84           429         블루베리     SUMMER          896

# %%
product_info.to_csv('data/basic_product_info.csv', encoding='utf-8', index=False)
